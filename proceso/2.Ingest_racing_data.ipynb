-- %%
%python
dbutils.widgets.removeAll()

-- %%
%python
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType
from pyspark.sql.functions import current_timestamp, to_timestamp, concat, col, lit

-- %%
%python
dbutils.widgets.text("container", "raw")
dbutils.widgets.text("catalogo", "catalog_au")
dbutils.widgets.text("esquema", "bronze")
dbutils.widgets.text("storageName", "adlsproyectoje")

-- %%
%python
container = dbutils.widgets.get("container")
catalogo = dbutils.widgets.get("catalogo")
esquema = dbutils.widgets.get("esquema")
storageName = dbutils.widgets.get("storageName")

ruta = f"abfss://{container}@{storageName}.dfs.core.windows.net/races.csv"

-- %%
%python
races_schema = StructType(fields=[StructField("raceId", IntegerType(), False),
                                  StructField("year", IntegerType(), True),
                                  StructField("round", IntegerType(), True),
                                  StructField("circuitId", IntegerType(), True),
                                  StructField("name", StringType(), True),
                                  StructField("date", DateType(), True),
                                  StructField("time", StringType(), True),
                                  StructField("url", StringType(), True) 
])

-- %%
%python
races_df = spark.read \
            .option("header", True) \
            .schema(races_schema) \
            .csv(ruta)

-- %%
%python
races_with_timestamp_df = races_df.withColumn("ingestion_date", current_timestamp())

-- %%
%python
races_selected_df = races_with_timestamp_df.select(col('raceId').alias('race_id'), 
                                                   col('year').alias('race_year'), 
                                                   col('round'), col('circuitId').alias('circuit_id'),
                                                   col('name'), col('ingestion_date'))

-- %%
%python
races_selected_df.write.mode('overwrite').partitionBy('race_year').saveAsTable(f'{catalogo}.{esquema}.races')

-- %%
%sql

INSERT INTO ${catalogo}.bronze.ABILITIES VALUES
(1, 'Adaptabilidad'),
(2, 'Aerovelo'),
(3, 'Mártir'),
(4, 'Paraguas'),
(5, 'Analítico'),
(6, 'Punto Ira'),
(7, 'Anticipación'),
(8, 'Trampa Arena'),
(9, 'Velo Aroma'),
(10, 'Como Uno'),
(11, 'Rompe Auras'),
(12, 'Pesadilla'),
(13, 'Recuperapelota'),
(14, 'Batería'),
(15, 'Armadura Batalla'),
(16, 'Vínculo Guerrero'),
(17, 'Superpoder'),
(18, 'Furia'),
(19, 'Picotón'),
(20, 'Llamarada'),
(21, 'Antibala'),
(22, 'Moflete'),
(23, 'Relincho Gélido'),
(24, 'Clorofila'),
(25, 'Cuerpo Puro'),
(26, 'Nuboso'),
(27, 'Cambio Color'),
(28, 'Narcoléptico'),
(29, 'Competitivo'),
(30, 'Contrario'),
(31, 'Corrosión'),
(32, 'Pelusa Algodón'),
(33, 'Medicina Curiosa'),
(34, 'Maldición'),
(35, 'Encantador'),
(36, 'Humedad'),
(37, 'Bailarín'),
(38, 'Aura Oscura'),
(39, 'Escudo Gallardo'),
(40, 'Deslumbrante'),
(41, 'Derrotista'),
(42, 'Desafío'),
(43, 'Vórtice Delta'),
(44, 'Tierra Baldía'),
(45, 'Disfraz'),
(46, 'Descarga'),
(47, 'Fauces Dragón'),
(48, 'Llovizna'),
(49, 'Sequía'),
(50, 'Piel Seca'),
(51, 'Madrugar'),
(52, 'Espora'),
(53, 'Electricidad'),
(54, 'Salida Urgente'),
(55, 'Aura Feérica'),
(56, 'Filtro'),
(57, 'Llama Viva'),
(58, 'Potencia Llama'),
(59, 'Absorbe Fuego'),
(60, 'Don Floral'),
(61, 'Velo Floral'),
(62, 'Esponjoso'),
(63, 'Predicción'),
(64, 'Presagio'),
(65, 'Escudo Amigo'),
(66, 'Cacheo'),
(67, 'Cuerpo Metálico'),
(68, 'Pelaje'),
(69, 'Alas Vendaval'),
(70, 'Galvanizar'),
(71, 'Gula'),
(72, 'Viscoso'),
(73, 'Táctica Gorila'),
(74, 'Pelaje Hierba'),
(75, 'Surgencia Hierba'),
(76, 'Relincho Nefasto'),
(77, 'Trago Misil'),
(78, 'Agallas'),
(79, 'Recolecta'),
(80, 'Sanador'),
(81, 'Resistencia'),
(82, 'Metal Pesado'),
(83, 'Mielero'),
(84, 'Gran Poder'),
(85, 'Cambio Hambre'),
(86, 'Entusiasmo'),
(87, 'Hidratación'),
(88, 'Cortante'),
(89, 'Cuerpo Hielo'),
(90, 'Máscara Hielo'),
(91, 'Escamas Hielo'),
(92, 'Iluminar'),
(93, 'Ilusión'),
(94, 'Inmunidad'),
(95, 'Impostor'),
(96, 'Infiltrado'),
(97, 'Tripas'),
(98, 'Foco Interior'),
(99, 'Insomnio'),
(100, 'Intimidación'),
(101, 'Espada Intrépida'),
(102, 'Pinchos Férreos'),
(103, 'Puño Férreo'),
(104, 'Justicia'),
(105, 'Vista Lince'),
(106, 'Torpe'),
(107, 'Escudo Hoja'),
(108, 'Levitación'),
(109, 'Líbero'),
(110, 'Metal Ligero'),
(111, 'Pararrayos'),
(112, 'Flexibilidad'),
(113, 'Supuración'),
(114, 'Voz Líquida'),
(115, 'Largo Alcance'),
(116, 'Rebote Mágico'),
(117, 'Guardia Mágica'),
(118, 'Mago'),
(119, 'Armadura Magma'),
(120, 'Imán'),
(121, 'Escama Maravilla'),
(122, 'Megalanzador'),
(123, 'Despiadado'),
(124, 'Mimetismo'),
(125, 'Menos'),
(126, 'Armadura Espejo'),
(127, 'Surgencia Velo'),
(128, 'Rompemoldes'),
(129, 'Volátil'),
(130, 'Motor'),
(131, 'Autoestima'),
(132, 'Multiescama'),
(133, 'Multitipo'),
(134, 'Momia'),
(135, 'Cura Natural'),
(136, 'Gas Neutralizante'),
(137, 'Sin Guardia'),
(138, 'Normalizar'),
(139, 'Despiste'),
(140, 'Sobretodo'),
(141, 'Espesura'),
(142, 'Ritmo Propio'),
(143, 'Lazo Paternal'),
(144, 'Velo Pastel'),
(145, 'Cuerpo Mortal'),
(146, 'Carterista'),
(147, 'Recogida'),
(148, 'Pixilar'),
(149, 'Más'),
(150, 'Cura Veneno'),
(151, 'Punto Veneno'),
(152, 'Toque Venenoso'),
(153, 'Construcción'),
(154, 'Punto Poder'),
(155, 'Alquimia'),
(156, 'Bromista'),
(157, 'Presión'),
(158, 'Mar Primigenio'),
(159, 'Armadura Prisma'),
(160, 'Cola Hélice'),
(161, 'Proteico'),
(162, 'Surgencia Psíquica'),
(163, 'Rock Punk'),
(164, 'Poder Puro'),
(165, 'Majestad Real'),
(166, 'Acción Rápida'),
(167, 'Pies Rápidos'),
(168, 'Sistema ARCEus'),
(169, 'Plato Lluvia'),
(170, 'Nerviosismo'),
(171, 'Receptor'),
(172, 'Temerario'),
(173, 'Frigorfuerza'),
(174, 'Regeneración'),
(175, 'Madurar'),
(176, 'Rivalidad'),
(177, 'Cabeza Roca'),
(178, 'Piel Tosca'),
(179, 'Fuga'),
(180, 'Fuerza Arena'),
(181, 'Ímpetu Arena'),
(182, 'Polvareda Arena'),
(183, 'Vendaval Arena'),
(184, 'Velo Arena'),
(185, 'Herbívoro'),
(186, 'Banco'),
(187, 'Pendenciero'),
(188, 'Limpiabarrera'),
(189, 'Dicha'),
(190, 'Escudo Sombra'),
(191, 'Sombra Trampa'),
(192, 'Mudar'),
(193, 'Fuerza Bruta'),
(194, 'Armadura Concha'),
(195, 'Polvo Escudo'),
(196, 'Escudos Caídos'),
(197, 'Simple'),
(198, 'Cadena'),
(199, 'Inicio Lento'),
(200, 'Ímpetu Nieve'),
(201, 'Francotirador'),
(202, 'Velo Nieve'),
(203, 'Ventisca'),
(204, 'Energía Solar'),
(205, 'Roca Sólida'),
(206, 'Alma Corazón'),
(207, 'Antisonido'),
(208, 'Impulso'),
(209, 'Apuntando'),
(210, 'Rezagado'),
(211, 'Inquebrantable'),
(212, 'Aguante'),
(213, 'Cambio de Postura'),
(214, 'Electricidad Estática'),
(215, 'Perseverancia'),
(216, 'Motor Vapor'),
(217, 'Metalero'),
(218, 'Espíritu Férreo'),
(219, 'Hedor'),
(220, 'Atrapa Objeto'),
(221, 'Drenalluvia'),
(222, 'Mandíbula Fuerte'),
(223, 'Robustez'),
(224, 'Ventosas'),
(225, 'Supersuerte'),
(226, 'Surfista Eléctrico'),
(227, 'Enjambre'),
(228, 'Velo Dulce'),
(229, 'Nado Rápido'),
(230, 'Simbiosis'),
(231, 'Sincronía'),
(232, 'Pies Torpes'),
(233, 'Pelo Enmarañado'),
(234, 'Técnico'),
(235, 'Telepatía'),
(236, 'Teravoltio'),
(237, 'Sebo'),
(238, 'Lente Tintada'),
(239, 'Torrente'),
(240, 'Garras Duras'),
(241, 'Potencia Tóxica'),
(242, 'Seguimiento'),
(243, 'Transistor'),
(244, 'Triaje'),
(245, 'Flojera'),
(246, 'Turbollama'),
(247, 'Ignorante'),
(248, 'Liviano'),
(249, 'Intranquilizar'),
(250, 'Puño Invisible'),
(251, 'Estrella Victoria'),
(252, 'Vital'),
(253, 'Absorbe Eléctrico'),
(254, 'Espíritu Errante'),
(255, 'Absorbe Agua'),
(256, 'Burbuja Agua'),
(257, 'Compactación'),
(258, 'Velo Acuático'),
(259, 'Armadura Frágil'),
(260, 'Humo Blanco'),
(261, 'Acobardarse'),
(262, 'Guardia Maravillosa'),
(263, 'Piel Maravilla'),
(264, 'Modo Zen');

-- COMMAND ----------

INSERT INTO ${catalogo}.bronze.EXPERIENCE_TYPES VALUES
(1, 'Errático'),
(2, 'Rápido'),
(3, 'Fluctuante'),
(4, 'Medio Rápido'),
(5, 'Medio Lento'),
(6, 'Lento');

-- COMMAND ----------

INSERT INTO ${catalogo}.bronze.GENERATIONS VALUES
(1, 1, 'Generación I – Rojo/Azul/Amarillo (Kanto, 1996)'),
(2, 2, 'Generación II – Oro/Plata/Cristal (Johto, 1999)'),
(3, 3, 'Generación III – Rubí/Zafiro/Esmeralda (Hoenn, 2002)'),
(4, 4, 'Generación IV – Diamante/Perla/Platino (Sinnoh, 2006)'),
(5, 5, 'Generación V – Negro/Blanco (Teselia, 2010)'),
(6, 6, 'Generación VI – X/Y (Kalos, 2013)'),
(7, 7, 'Generación VII – Sol/Luna (Alola, 2016)'),
(8, 8, 'Generación VIII – Espada/Escudo (Galar, 2019)');

-- COMMAND ----------
